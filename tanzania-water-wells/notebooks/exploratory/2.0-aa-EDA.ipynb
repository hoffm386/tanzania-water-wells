# %% [markdown]
# # Load Data and Modules Needed

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
file_train = "~/Documents/ds_10_28/proj3/tanzania-water-wells/data/training-set-values.csv" #x_train, training set values data
file_target_train = "~/Documents/ds_10_28/proj3/tanzania-water-wells/data/training-labels.csv" #y_train, training set labels
file_test = "~/Documents/ds_10_28/proj3/tanzania-water-wells/data/test-set.csv" #x_test, test set data

# %%
features = pd.read_csv(file_train)
targets = pd.read_csv(file_target_train)
X_test = pd.read_csv(file_test)

# %% [markdown]
# # EDA

# %%
targets['status_group'].value_counts()
# Out:
# functional                 32259
# non functional             22824
# functional needs repair     4317
# Name: status_group, dtype: int64

# %%
print(features.dtypes)
print(f"\nNumber of features: {len(features.dtypes)}")
# Out:
# id                         int64
# amount_tsh               float64
# date_recorded             object
# funder                    object
# gps_height                 int64
# installer                 object
# longitude                float64
# latitude                 float64
# wpt_name                  object
# num_private                int64
# basin                     object
# subvillage                object
# region                    object
# region_code                int64
# district_code              int64
# lga                       object
# ward                      object
# population                 int64
# public_meeting            object
# recorded_by               object
# scheme_management         object
# scheme_name               object
# permit                    object
# construction_year          int64
# extraction_type           object
# extraction_type_group     object
# extraction_type_class     object
# management                object
# management_group          object
# payment                   object
# payment_type              object
# water_quality             object
# quality_group             object
# quantity                  object
# quantity_group            object
# source                    object
# source_type               object
# source_class              object
# waterpoint_type           object
# waterpoint_type_group     object
# dtype: object
#
# Number of features: 40

# %% [markdown]
# ## Definitely an imbalance in the training target data, and there are a lot of categorical features!
#
# #### There are also several features that look very related, source/source_type, waterpoint_type/waterpoint_type_group, payment/payment_type, etc.

# %%
wells = features.copy()

# %%
print(f"Waterpoint type group:\n{wells['waterpoint_type_group'].value_counts()}")
print(f"Count: {len(wells['waterpoint_type_group'].unique())}")

print(f"\nWaterpoint type:\n{wells['waterpoint_type'].value_counts()}")
print(f"Count: {len(wells['waterpoint_type'].unique())}")
# Out:
# Waterpoint type group:
# communal standpipe    34625
# hand pump             17488
# other                  6380
# improved spring         784
# cattle trough           116
# dam                       7
# Name: waterpoint_type_group, dtype: int64
# Count: 6
#
# Waterpoint type:
# communal standpipe             28522
# hand pump                      17488
# other                           6380
# communal standpipe multiple     6103
# improved spring                  784
# cattle trough                    116
# dam                                7
# Name: waterpoint_type, dtype: int64
# Count: 7

# %% [markdown]
# #### "quantity" and "quantity_group" are literally copies of eachother

# %%
print(f"Quantity:\n{wells['quantity'].value_counts()}")
print(f"Count: {len(wells['quantity'].unique())}")

print(f"\nQuantity Group:\n{wells['quantity_group'].value_counts()}")
print(f"Count: {len(wells['quantity_group'].unique())}")
# Out:
# Quantity:
# enough          33186
# insufficient    15129
# dry              6246
# seasonal         4050
# unknown           789
# Name: quantity, dtype: int64
# Count: 5
#
# Quantity Group:
# enough          33186
# insufficient    15129
# dry              6246
# seasonal         4050
# unknown           789
# Name: quantity_group, dtype: int64
# Count: 5

# %% [markdown]
# Management is harder to tell..

# %%
print(f"Management group:\n{wells['management_group'].value_counts()}")
print(f"Count: {len(wells['waterpoint_type_group'].unique())}")

print(f"\nManagement:\n{wells['management'].value_counts()}")
print(f"Count: {len(wells['management'].unique())}")
# Out:
# Management group:
# user-group    52490
# commercial     3638
# parastatal     1768
# other           943
# unknown         561
# Name: management_group, dtype: int64
# Count: 6
#
# Management:
# vwc                 40507
# wug                  6515
# water board          2933
# wua                  2535
# private operator     1971
# parastatal           1768
# water authority       904
# other                 844
# company               685
# unknown               561
# other - school         99
# trust                  78
# Name: management, dtype: int64
# Count: 12

# %% [markdown]
# I like type, besides dam all of the types seem to numerous

# %%
print(f"Source class:\n{wells['source_class'].value_counts()}")
print(f"Count: {len(wells['source_class'].unique())}")

print(f"\nSource type:\n{wells['source_type'].value_counts()}")
print(f"Count: {len(wells['source_type'].unique())}")

print(f"\nSource:\n{wells['source'].value_counts()}")
print(f"Count: {len(wells['source'].unique())}")
# Out:
# Source class:
# groundwater    45794
# surface        13328
# unknown          278
# Name: source_class, dtype: int64
# Count: 3
#
# Source type:
# spring                  17021
# shallow well            16824
# borehole                11949
# river/lake              10377
# rainwater harvesting     2295
# dam                       656
# other                     278
# Name: source_type, dtype: int64
# Count: 7
#
# Source:
# spring                  17021
# shallow well            16824
# machine dbh             11075
# river                    9612
# rainwater harvesting     2295
# hand dtw                  874
# lake                      765
# dam                       656
# other                     212
# unknown                    66
# Name: source, dtype: int64
# Count: 10

# %%
print(f"Payment:\n{wells['payment'].value_counts()}")
print(f"Count: {len(wells['payment'].unique())}")

print(f"\nPayment Type:\n{wells['payment_type'].value_counts()}")
print(f"Count: {len(wells['payment_type'].unique())}")
# Out:
# Payment:
# never pay                25348
# pay per bucket            8985
# pay monthly               8300
# unknown                   8157
# pay when scheme fails     3914
# pay annually              3642
# other                     1054
# Name: payment, dtype: int64
# Count: 7
#
# Payment Type:
# never pay     25348
# per bucket     8985
# monthly        8300
# unknown        8157
# on failure     3914
# annually       3642
# other          1054
# Name: payment_type, dtype: int64
# Count: 7

# %%
print(f"Quality Group:\n{wells['quality_group'].value_counts()}")
print(f"Count: {len(wells['quality_group'].unique())}")

print(f"\nWater Quality:\n{wells['water_quality'].value_counts()}")
print(f"Count: {len(wells['water_quality'].unique())}")
# Out:
# Quality Group:
# good        50818
# salty        5195
# unknown      1876
# milky         804
# colored       490
# fluoride      217
# Name: quality_group, dtype: int64
# Count: 6
#
# Water Quality:
# soft                  50818
# salty                  4856
# unknown                1876
# milky                   804
# coloured                490
# salty abandoned         339
# fluoride                200
# fluoride abandoned       17
# Name: water_quality, dtype: int64
# Count: 8

# %%
print(f"Funder:\n{wells['funder'].value_counts()}")
print(f"Count: {len(wells['funder'].unique())}")

print(f"\nInstaller:\n{wells['installer'].value_counts()}")
print(f"Count: {len(wells['installer'].unique())}")
# Out:
# Funder:
# Government Of Tanzania       9084
# Danida                       3114
# Hesawa                       2202
# Rwssp                        1374
# World Bank                   1349
# Kkkt                         1287
# World Vision                 1246
# Unicef                       1057
# Tasaf                         877
# District Council              843
# Dhv                           829
# Private Individual            826
# Dwsp                          811
# 0                             777
# Norad                         765
# Germany Republi               610
# Tcrs                          602
# Ministry Of Water             590
# Water                         583
# Dwe                           484
# Netherlands                   470
# Hifab                         450
# Adb                           448
# Lga                           442
# Amref                         425
# Fini Water                    393
# Oxfam                         359
# Wateraid                      333
# Rc Church                     321
# Isf                           316
#                              ...
# Tancan                          1
# Samsoni                         1
# Prodap                          1
# Msudi                           1
# Long Ga                         1
# Dae Yeol And Chae Lynn          1
# Nyangere                        1
# Mungaya                         1
# Bukumbi                         1
# Elca                            1
# Community Bank                  1
# World Vision/rc Church          1
# Sindida Yetu                    1
# Hasnein Murij                   1
# Sweeden                         1
# Wamakapuchini                   1
# Mzee Lesilali                   1
# Gurdians                        1
# Mtambo                          1
# Lgdbg                           1
# Csf                             1
# Karadea Ngo                     1
# Cdft                            1
# Robert Mosi                     1
# Dgv                             1
# Loocip                          1
# Wamisionari Wa Kikatoriki       1
# Su-ki Jang                      1
# Mgaya                           1
# Omar Ally                       1
# Name: funder, Length: 1897, dtype: int64
# Count: 1898
#
# Installer:
# DWE                             17402
# Government                       1825
# RWE                              1206
# Commu                            1060
# DANIDA                           1050
# KKKT                              898
# Hesawa                            840
# 0                                 777
# TCRS                              707
# Central government                622
# CES                               610
# Community                         553
# DANID                             552
# District Council                  551
# HESAWA                            539
# LGA                               408
# World vision                      408
# WEDECO                            397
# TASAF                             396
# District council                  392
# Gover                             383
# AMREF                             329
# TWESA                             316
# WU                                301
# Dmdd                              287
# ACRA                              278
# World Vision                      270
# SEMA                              249
# DW                                246
# OXFAM                             234
#                                 ...
# Kanisani                            1
# Nyamingu subvillage                 1
# KDPA                                1
# CH                                  1
# CHINA HENAN CONSTUCTION             1
# Athumani Issa                       1
# REDEP                               1
# TCRS/ TASSAF                        1
# Lindi rural water department        1
# peter                               1
# mwita kichere                       1
# DBSP                                1
# marafip                             1
# Privat                              1
# MANGO TREE                          1
# TCRS/TWESA                          1
# Makori                              1
# WASHIMA                             1
# Hery                                1
# KUMKUM                              1
# Okong'o                             1
# BGSS                                1
# TOVE                                1
# Ju                                  1
# Nimrod Mkono[mb]                    1
# Natio                               1
# Kanamama                            1
# KAWINGA                             1
# Omar Rafael                         1
# WIZARA                              1
# Name: installer, Length: 2145, dtype: int64
# Count: 2146

# %%
print(wells['subvillage'].value_counts())
print(len(wells['subvillage'].unique()))
# Out:
# Madukani             508
# Shuleni              506
# Majengo              502
# Kati                 373
# Mtakuja              262
# Sokoni               232
# M                    187
# Muungano             172
# Mbuyuni              164
# Mlimani              152
# Songambele           147
# Miembeni             134
# Msikitini            134
# 1                    132
# Kibaoni              114
# Kanisani             111
# I                    109
# Mapinduzi            109
# Mjini                108
# Mjimwema             108
# Mkwajuni             104
# Mwenge               102
# Mabatini              98
# Azimio                98
# Mission               95
# Mbugani               95
# Bwawani               91
# Bondeni               90
# Chang'Ombe            88
# Zahanati              86
#                     ...
# Kanina                 1
# Kwea                   1
# Chamtumile             1
# Namtovu                1
# Semaki                 1
# Ntutulu                1
# No 9 Camp              1
# Nagasunga              1
# Kimbosi                1
# Asao                   1
# Gidim                  1
# Milengwelengwe A       1
# Bwisabuka              1
# Nyabiriza              1
# Kang'Endo              1
# Kizito Huonjwa         1
# Ofisini Mashariki      1
# Murutongole            1
# Vumilia Kati           1
# Kilombero B            1
# Misongeni              1
# Nyarusonzo             1
# Karashi                1
# Unyakhae               1
# Kwa Bonda              1
# Mbuyahela              1
# Pangale                1
# Ascarida               1
# Nyagudi                1
# Irugwanzara            1
# Name: subvillage, Length: 19287, dtype: int64
# 19288

# %% [markdown]
# ### Let's look at how the numerical data is correlated:

# %%
wells.corr()
# Out:
#                          id  amount_tsh  gps_height  longitude  latitude  \
# id                 1.000000   -0.005321   -0.004692  -0.001348  0.001718
# amount_tsh        -0.005321    1.000000    0.076650   0.022134 -0.052670
# gps_height        -0.004692    0.076650    1.000000   0.149155 -0.035751
# longitude         -0.001348    0.022134    0.149155   1.000000 -0.425802
# latitude           0.001718   -0.052670   -0.035751  -0.425802  1.000000
# num_private       -0.002629    0.002944    0.007237   0.023873  0.006837
# region_code       -0.003028   -0.026813   -0.183521   0.034197 -0.221018
# district_code     -0.003044   -0.023599   -0.171233   0.151398 -0.201020
# population        -0.002813    0.016288    0.135003   0.086590 -0.022152
# construction_year -0.002082    0.067915    0.658727   0.396732 -0.245278
#
#                    num_private  region_code  district_code  population  \
# id                   -0.002629    -0.003028      -0.003044   -0.002813
# amount_tsh            0.002944    -0.026813      -0.023599    0.016288
# gps_height            0.007237    -0.183521      -0.171233    0.135003
# longitude             0.023873     0.034197       0.151398    0.086590
# latitude              0.006837    -0.221018      -0.201020   -0.022152
# num_private           1.000000    -0.020377      -0.004478    0.003818
# region_code          -0.020377     1.000000       0.678602    0.094088
# district_code        -0.004478     0.678602       1.000000    0.061831
# population            0.003818     0.094088       0.061831    1.000000
# construction_year     0.026056     0.031724       0.048315    0.260910
#
#                    construction_year
# id                         -0.002082
# amount_tsh                  0.067915
# gps_height                  0.658727
# longitude                   0.396732
# latitude                   -0.245278
# num_private                 0.026056
# region_code                 0.031724
# district_code               0.048315
# population                  0.260910
# construction_year           1.000000

# %% [markdown]
# district_code and region_code have a high correlation, but instinctually this would make sense as they are probably related. population shows some correlation to construction_year, but this is probably not normalized to the growth in population over time. Something to note is that construction_year and gps_height have the highest correlation - is there something allowing them to build at higher elevations that was not possible previously?
#
# This made us consider other technological innovations. extraction_type, extraction_type_class and extraction_type_group possibly fit the bill.

# %%
print(wells['construction_year'].value_counts())
print(len(wells['construction_year'].unique()))
# Out:
# 0       20709
# 2010     2645
# 2008     2613
# 2009     2533
# 2000     2091
# 2007     1587
# 2006     1471
# 2003     1286
# 2011     1256
# 2004     1123
# 2012     1084
# 2002     1075
# 1978     1037
# 1995     1014
# 2005     1011
# 1999      979
# 1998      966
# 1990      954
# 1985      945
# 1980      811
# 1996      811
# 1984      779
# 1982      744
# 1994      738
# 1972      708
# 1974      676
# 1997      644
# 1992      640
# 1993      608
# 2001      540
# 1988      521
# 1983      488
# 1975      437
# 1986      434
# 1976      414
# 1970      411
# 1991      324
# 1989      316
# 1987      302
# 1981      238
# 1977      202
# 1979      192
# 1973      184
# 2013      176
# 1971      145
# 1960      102
# 1967       88
# 1963       85
# 1968       77
# 1969       59
# 1964       40
# 1962       30
# 1961       21
# 1965       19
# 1966       17
# Name: construction_year, dtype: int64
# 55

# %% [markdown]
# ### Uh-oh
# Over one-third of the data has a "0" for construction year. What are these three different groups, and how are the non-zeroes correlated with extraction type?

# %%
print(f"Extraction type class:\n{wells['extraction_type_class'].value_counts()}")
print(f"Count: {len(wells['extraction_type_class'].unique())}")

print(f"\nExtraction type group:\n{wells['extraction_type_group'].value_counts()}")
print(f"Count: {len(wells['extraction_type_group'].unique())}")

print(f"\nExtraction type:\n{wells['extraction_type'].value_counts()}")
print(f"Count: {len(wells['extraction_type'].unique())}")
# Out:
# Extraction type class:
# gravity         26780
# handpump        16456
# other            6430
# submersible      6179
# motorpump        2987
# rope pump         451
# wind-powered      117
# Name: extraction_type_class, dtype: int64
# Count: 7
#
# Extraction type group:
# gravity            26780
# nira/tanira         8154
# other               6430
# submersible         6179
# swn 80              3670
# mono                2865
# india mark ii       2400
# afridev             1770
# rope pump            451
# other handpump       364
# other motorpump      122
# wind-powered         117
# india mark iii        98
# Name: extraction_type_group, dtype: int64
# Count: 13
#
# Extraction type:
# gravity                      26780
# nira/tanira                   8154
# other                         6430
# submersible                   4764
# swn 80                        3670
# mono                          2865
# india mark ii                 2400
# afridev                       1770
# ksb                           1415
# other - rope pump              451
# other - swn 81                 229
# windmill                       117
# india mark iii                  98
# cemo                            90
# other - play pump               85
# walimi                          48
# climax                          32
# other - mkulima/shinyanga        2
# Name: extraction_type, dtype: int64
# Count: 18

# %%
con_year_nonzero = wells.copy()
con_year_nonzero = con_year_nonzero.replace(0, np.nan)

print(con_year_nonzero['construction_year'].value_counts().sum())

# con_year_nonzero = con_year_nonzero.dropna(how='all', axis=1)
# print(con_year_nonzero['construction_year'].value_counts().sum())
# Out:
# 38691

# %%
display(plt.scatter(con_year_nonzero['construction_year'],con_year_nonzero['extraction_type_class']))

# %%
display(plt.scatter(con_year_nonzero['construction_year'],con_year_nonzero['extraction_type_group']))

# %%
display(plt.scatter(con_year_nonzero['construction_year'],con_year_nonzero['extraction_type']))

# %%
avg_con_years = pd.DataFrame(con_year_nonzero.groupby(['extraction_type']).mean()['construction_year'])
avg_con_years
# Out:
#                            construction_year
# extraction_type
# afridev                          2002.316821
# cemo                             2009.000000
# climax                           2012.000000
# gravity                          1995.965949
# india mark ii                    2001.308428
# india mark iii                   2004.126984
# ksb                              1999.250000
# mono                             1992.634541
# nira/tanira                      1999.421166
# other                            1993.136859
# other - mkulima/shinyanga        1971.000000
# other - play pump                2002.620000
# other - rope pump                2005.810256
# other - swn 81                   2000.346591
# submersible                      1999.321214
# swn 80                           1996.671370
# walimi                           2000.000000
# windmill                         1995.377049

# %%
wells_test = wells.copy()
wells_test = pd.concat([wells_test,avg_con_years],keys=['extraction_type'])
avg_con_years['construction_year'] = avg_con_years['construction_year'].astype(int)
wells_test = wells_test.join(avg_con_years, rsuffix='_avg', on='extraction_type') 
wells_test = wells_test.reset_index()
wells_test = wells_test.drop(['level_0','level_1'],axis=1)
wells_test
# Out:
#           id  amount_tsh date_recorded                    funder  gps_height  \
# 0      69572      6000.0    2011-03-14                     Roman        1390
# 1       8776         0.0    2013-03-06                   Grumeti        1399
# 2      34310        25.0    2013-02-25              Lottery Club         686
# 3      67743         0.0    2013-01-28                    Unicef         263
# 4      19728         0.0    2011-07-13               Action In A           0
# 5       9944        20.0    2011-03-13       Mkinga Distric Coun           0
# 6      19816         0.0    2012-10-01                      Dwsp           0
# 7      54551         0.0    2012-10-09                     Rwssp           0
# 8      53934         0.0    2012-11-03                  Wateraid           0
# 9      46144         0.0    2011-08-03               Isingiro Ho           0
# 10     49056         0.0    2011-02-20                   Private          62
# 11     50409       200.0    2013-02-18                    Danida        1062
# 12     36957         0.0    2012-10-14              World Vision           0
# 13     50495         0.0    2013-03-15   Lawatefuka Water Supply        1368
# 14     53752         0.0    2012-10-20                     Biore           0
# 15     61848         0.0    2011-08-04                     Rudep        1645
# 16     48451       500.0    2011-07-04                    Unicef        1703
# 17     58155         0.0    2011-09-04                    Unicef        1656
# 18     34169         0.0    2011-07-22                    Hesawa        1162
# 19     18274       500.0    2011-02-22                    Danida        1763
# 20     48375       200.0    2011-02-27                       Twe        2216
# 21      6091         0.0    2013-02-10                      Dwsp           0
# 22     58500         0.0    2011-10-04                    Unicef        1510
# 23     37862       500.0    2013-11-03                       Isf         672
# 24     51058         0.0    2013-01-21  African Development Bank        1645
# 25     22308         0.0    2013-02-25    Government Of Tanzania        1273
# 26     55012       500.0    2013-01-16                    Sobodo         200
# 27     20145         0.0    2011-07-11                    Hesawa           0
# 28     19685         0.0    2013-03-05    Government Of Tanzania        1443
# 29     69124         0.0    2013-03-16   Lawatefuka Water Supply        1256
# ...      ...         ...           ...                       ...         ...
# 59370  14796       200.0    2013-01-29                       NaN        1154
# 59371  20387         0.0    2012-10-09               Netherlands           0
# 59372  29940         0.0    2012-10-31                       Tlc           0
# 59373  15233      5000.0    2013-01-30                     Rudep        1137
# 59374  49651         0.0    2012-10-29                     Rwssp           0
# 59375  50998     40000.0    2011-08-03    Government Of Tanzania          54
# 59376  34716         0.0    2013-02-03                       NaN        1581
# 59377  43986         0.0    2012-10-23    Government Of Tanzania           0
# 59378  38067       500.0    2011-03-21                        Rc        2101
# 59379  58255         0.0    2011-07-13                        Do           0
# 59380  30647      6000.0    2011-03-14                     Roman        1439
# 59381  67885         0.0    2011-03-16       Mkinga Distric Coun           0
# 59382  47002         6.0    2013-08-03                 Ces(gmbh)        1383
# 59383  44616         0.0    2013-01-19                World Bank          11
# 59384  72148         0.0    2011-07-10                   Concern           0
# 59385  34473       500.0    2012-11-03                     Jaica        1327
# 59386  34952         0.0    2011-08-22                       Adb        1786
# 59387  26640       100.0    2013-03-12                         0          25
# 59388  72559         0.0    2013-01-29                     Kidep        1414
# 59389  30410         0.0    2011-08-06                        Co         783
# 59390  13677         0.0    2011-08-04                     Rudep        1715
# 59391  44885         0.0    2013-08-03    Government Of Tanzania         540
# 59392  40607         0.0    2011-04-15    Government Of Tanzania           0
# 59393  48348         0.0    2012-10-27                   Private           0
# 59394  11164       500.0    2011-03-09                World Bank         351
# 59395  60739        10.0    2013-05-03           Germany Republi        1210
# 59396  27263      4700.0    2011-05-07               Cefa-njombe        1212
# 59397  37057         0.0    2011-04-11                       NaN           0
# 59398  31282         0.0    2011-03-08                     Malec           0
# 59399  26348         0.0    2011-03-23                World Bank         191
#
#                   installer  longitude      latitude  \
# 0                     Roman  34.938093 -9.856322e+00
# 1                   GRUMETI  34.698766 -2.147466e+00
# 2              World vision  37.460664 -3.821329e+00
# 3                    UNICEF  38.486161 -1.115530e+01
# 4                   Artisan  31.130847 -1.825359e+00
# 5                       DWE  39.172796 -4.765587e+00
# 6                      DWSP  33.362410 -3.766365e+00
# 7                       DWE  32.620617 -4.226198e+00
# 8                 Water Aid  32.711100 -5.146712e+00
# 9                   Artisan  30.626991 -1.257051e+00
# 10                  Private  39.209518 -7.034139e+00
# 11                   DANIDA  35.770258 -1.057417e+01
# 12             World vision  33.798106 -3.290194e+00
# 13     Lawatefuka water sup  37.092574 -3.181783e+00
# 14                   WEDECO  34.364073 -3.629333e+00
# 15                      DWE  31.444121 -8.274962e+00
# 16                      DWE  34.642439 -9.106185e+00
# 17                      DWE  34.569266 -9.085515e+00
# 18                      DWE  32.920154 -1.947868e+00
# 19                    Danid  34.508967 -9.894412e+00
# 20                      TWE  34.473430 -9.594990e+00
# 21                      DWE   0.000000 -2.000000e-08
# 22                      DWE  34.586901 -8.980014e+00
# 23                      ISF  37.940029 -4.125595e+00
# 24                      DWE  29.747066 -4.495568e+00
# 25                      DWE  37.422751 -3.317536e+00
# 26              Kilolo Star  39.370777 -9.942532e+00
# 27                      DWE  31.104257 -1.735361e+00
# 28         District council  37.611126 -3.263526e+00
# 29     Lawatefuka water sup  37.061688 -3.191989e+00
# ...                     ...        ...           ...
# 59370                   NaN  30.058731 -4.902633e+00
# 59371                   DWE  33.586406 -3.040369e+00
# 59372                   TLC  32.058548 -5.052101e+00
# 59373                Distri  32.125024 -6.784358e+00
# 59374                   DWE   0.000000 -2.000000e-08
# 59375                   DWE  39.046942 -5.061494e+00
# 59376                   NaN  34.821039 -5.076258e+00
# 59377            Government  33.437012 -4.423594e+00
# 59378                  ACRA  34.620387 -9.358405e+00
# 59379                    DO  31.613284 -1.820226e+00
# 59380                 Roman  34.942101 -9.849198e+00
# 59381                   DWE  38.835001 -4.880204e+00
# 59382                   DWE  37.454759 -3.323599e+00
# 59383            World bank  39.626009 -1.005750e+01
# 59384               CONCERN  30.667805 -2.483710e+00
# 59385              JAICA CO  33.951681 -2.021854e+00
# 59386                   DWE  31.738789 -8.532013e+00
# 59387                     0  39.176480 -6.957098e+00
# 59388                   DWE  30.692400 -3.593827e+00
# 59389                   DWE  30.646486 -7.365418e+00
# 59390                   DWE  31.370848 -8.258160e+00
# 59391            Government  38.044070 -4.272218e+00
# 59392            Government  33.009440 -8.520888e+00
# 59393               Private  33.866852 -4.287410e+00
# 59394              ML appro  37.634053 -6.124830e+00
# 59395                   CES  37.169807 -3.253847e+00
# 59396                  Cefa  35.249991 -9.070629e+00
# 59397                   NaN  34.017087 -8.750434e+00
# 59398                  Musa  35.861315 -6.378573e+00
# 59399                 World  38.104048 -6.747464e+00
#
#                         wpt_name  num_private          ...           \
# 0                           none            0          ...
# 1                       Zahanati            0          ...
# 2                    Kwa Mahundi            0          ...
# 3           Zahanati Ya Nanyumbu            0          ...
# 4                        Shuleni            0          ...
# 5                         Tajiri            0          ...
# 6                     Kwa Ngomho            0          ...
# 7                   Tushirikiane            0          ...
# 8              Kwa Ramadhan Musa            0          ...
# 9                        Kwapeto            0          ...
# 10                 Mzee Hokororo            0          ...
# 11              Kwa Alid Nchimbi            0          ...
# 12                         Pamba            0          ...
# 13          Kwa John Izack Mmari            0          ...
# 14                     Mwabasabi            0          ...
# 15        Kwa Juvenal Ching'Ombe            0          ...
# 16               Kwa John Mtenzi            0          ...
# 17               Kwa Rose Chaula            0          ...
# 18                        Ngomee            0          ...
# 19                          none            0          ...
# 20                          none            0          ...
# 21                      Muungano            0          ...
# 22                       Shuleni            0          ...
# 23                       Kinonga            0          ...
# 24                       Kamsasa            0          ...
# 25                     Kwa Tukai            0          ...
# 26         Ruhoma Primary School            0          ...
# 27                    Kwawilliam            0          ...
# 28                  Kwa Kibakaya            0          ...
# 29             Kwa Willium Kinda            0          ...
# ...                          ...          ...          ...
# 59370             Village Office            0          ...
# 59371                   Ushirika            0          ...
# 59372           Kwa Mzee Kamanya            0          ...
# 59373                Kwa Kadiega            0          ...
# 59374                 Nguvu Kazi            0          ...
# 59375                  Sekondari            0          ...
# 59376                    Nasingo            0          ...
# 59377                       Fpct            0          ...
# 59378             Michael Msigwa            0          ...
# 59379            Coffee Plantati            0          ...
# 59380                       none            0          ...
# 59381                 Mijohoroni            0          ...
# 59382             Kwa Luka Msaki            0          ...
# 59383                    Shuleni            0          ...
# 59384                   Chamkube            0          ...
# 59385                Kwa Marunda            0          ...
# 59386  Shule Ya Sekondari Katazi            0          ...
# 59387                 Kwa Maliba            0          ...
# 59388         Kwa Philipo Kibeba            0          ...
# 59389                  Sekondari            0          ...
# 59390            Kwa Mzee Atanas            0          ...
# 59391                        Kwa            0          ...
# 59392             Benard Charles            0          ...
# 59393                  Kwa Peter            0          ...
# 59394                 Chimeredya            0          ...
# 59395        Area Three Namba 27            0          ...
# 59396          Kwa Yahona Kuvala            0          ...
# 59397                    Mashine            0          ...
# 59398                     Mshoro            0          ...
# 59399            Kwa Mzee Lugawa            0          ...
#
#       water_quality quality_group      quantity  quantity_group  \
# 0              soft          good        enough          enough
# 1              soft          good  insufficient    insufficient
# 2              soft          good        enough          enough
# 3              soft          good           dry             dry
# 4              soft          good      seasonal        seasonal
# 5             salty         salty        enough          enough
# 6              soft          good        enough          enough
# 7             milky         milky        enough          enough
# 8             salty         salty      seasonal        seasonal
# 9              soft          good        enough          enough
# 10            salty         salty        enough          enough
# 11             soft          good  insufficient    insufficient
# 12             soft          good        enough          enough
# 13             soft          good        enough          enough
# 14             soft          good        enough          enough
# 15             soft          good        enough          enough
# 16             soft          good           dry             dry
# 17             soft          good           dry             dry
# 18            milky         milky  insufficient    insufficient
# 19             soft          good        enough          enough
# 20             soft          good        enough          enough
# 21          unknown       unknown       unknown         unknown
# 22             soft          good        enough          enough
# 23             soft          good        enough          enough
# 24             soft          good        enough          enough
# 25             soft          good        enough          enough
# 26             soft          good        enough          enough
# 27             soft          good        enough          enough
# 28             soft          good  insufficient    insufficient
# 29             soft          good        enough          enough
# ...             ...           ...           ...             ...
# 59370       unknown       unknown       unknown         unknown
# 59371          soft          good        enough          enough
# 59372         salty         salty  insufficient    insufficient
# 59373          soft          good        enough          enough
# 59374          soft          good        enough          enough
# 59375          soft          good        enough          enough
# 59376       unknown       unknown           dry             dry
# 59377          soft          good  insufficient    insufficient
# 59378          soft          good        enough          enough
# 59379          soft          good        enough          enough
# 59380          soft          good           dry             dry
# 59381          soft          good  insufficient    insufficient
# 59382          soft          good        enough          enough
# 59383          soft          good        enough          enough
# 59384          soft          good  insufficient    insufficient
# 59385         salty         salty        enough          enough
# 59386          soft          good        enough          enough
# 59387          soft          good        enough          enough
# 59388          soft          good  insufficient    insufficient
# 59389          soft          good        enough          enough
# 59390          soft          good  insufficient    insufficient
# 59391          soft          good        enough          enough
# 59392          soft          good        enough          enough
# 59393          soft          good  insufficient    insufficient
# 59394          soft          good        enough          enough
# 59395          soft          good        enough          enough
# 59396          soft          good        enough          enough
# 59397      fluoride      fluoride        enough          enough
# 59398          soft          good  insufficient    insufficient
# 59399         salty         salty        enough          enough
#
#                      source           source_type source_class  \
# 0                    spring                spring  groundwater
# 1      rainwater harvesting  rainwater harvesting      surface
# 2                       dam                   dam      surface
# 3               machine dbh              borehole  groundwater
# 4      rainwater harvesting  rainwater harvesting      surface
# 5                     other                 other      unknown
# 6               machine dbh              borehole  groundwater
# 7              shallow well          shallow well  groundwater
# 8               machine dbh              borehole  groundwater
# 9              shallow well          shallow well  groundwater
# 10              machine dbh              borehole  groundwater
# 11             shallow well          shallow well  groundwater
# 12             shallow well          shallow well  groundwater
# 13                   spring                spring  groundwater
# 14             shallow well          shallow well  groundwater
# 15              machine dbh              borehole  groundwater
# 16                    river            river/lake      surface
# 17                    river            river/lake      surface
# 18                   spring                spring  groundwater
# 19                   spring                spring  groundwater
# 20                   spring                spring  groundwater
# 21             shallow well          shallow well  groundwater
# 22                    river            river/lake      surface
# 23                    river            river/lake      surface
# 24                   spring                spring  groundwater
# 25                   spring                spring  groundwater
# 26              machine dbh              borehole  groundwater
# 27             shallow well          shallow well  groundwater
# 28                   spring                spring  groundwater
# 29                   spring                spring  groundwater
# ...                     ...                   ...          ...
# 59370               unknown                 other      unknown
# 59371          shallow well          shallow well  groundwater
# 59372          shallow well          shallow well  groundwater
# 59373           machine dbh              borehole  groundwater
# 59374          shallow well          shallow well  groundwater
# 59375                 river            river/lake      surface
# 59376          shallow well          shallow well  groundwater
# 59377                   dam                   dam      surface
# 59378                spring                spring  groundwater
# 59379                spring                spring  groundwater
# 59380                spring                spring  groundwater
# 59381                spring                spring  groundwater
# 59382                spring                spring  groundwater
# 59383  rainwater harvesting  rainwater harvesting      surface
# 59384                spring                spring  groundwater
# 59385           machine dbh              borehole  groundwater
# 59386           machine dbh              borehole  groundwater
# 59387           machine dbh              borehole  groundwater
# 59388                spring                spring  groundwater
# 59389           machine dbh              borehole  groundwater
# 59390           machine dbh              borehole  groundwater
# 59391                 river            river/lake      surface
# 59392                spring                spring  groundwater
# 59393                   dam                   dam      surface
# 59394           machine dbh              borehole  groundwater
# 59395                spring                spring  groundwater
# 59396                 river            river/lake      surface
# 59397           machine dbh              borehole  groundwater
# 59398          shallow well          shallow well  groundwater
# 59399          shallow well          shallow well  groundwater
#
#                    waterpoint_type waterpoint_type_group construction_year_avg
# 0               communal standpipe    communal standpipe                  1995
# 1               communal standpipe    communal standpipe                  1995
# 2      communal standpipe multiple    communal standpipe                  1995
# 3      communal standpipe multiple    communal standpipe                  1999
# 4               communal standpipe    communal standpipe                  1995
# 5      communal standpipe multiple    communal standpipe                  1999
# 6                        hand pump             hand pump                  1996
# 7                        hand pump             hand pump                  1999
# 8                        hand pump             hand pump                  2001
# 9                        hand pump             hand pump                  1999
# 10                           other                 other                  1999
# 11                       hand pump             hand pump                  1996
# 12                       hand pump             hand pump                  1999
# 13              communal standpipe    communal standpipe                  1995
# 14                       hand pump             hand pump                  1999
# 15                       hand pump             hand pump                  1996
# 16              communal standpipe    communal standpipe                  1995
# 17              communal standpipe    communal standpipe                  1995
# 18                           other                 other                  1993
# 19              communal standpipe    communal standpipe                  1995
# 20              communal standpipe    communal standpipe                  1995
# 21                       hand pump             hand pump                  1996
# 22              communal standpipe    communal standpipe                  1995
# 23              communal standpipe    communal standpipe                  1995
# 24                 improved spring       improved spring                  1995
# 25              communal standpipe    communal standpipe                  1995
# 26                       hand pump             hand pump                  2001
# 27                       hand pump             hand pump                  1999
# 28              communal standpipe    communal standpipe                  1995
# 29              communal standpipe    communal standpipe                  1995
# ...                            ...                   ...                   ...
# 59370                        other                 other                  1993
# 59371                    hand pump             hand pump                  1999
# 59372                        other                 other                  1993
# 59373                    hand pump             hand pump                  2001
# 59374                    hand pump             hand pump                  1999
# 59375           communal standpipe    communal standpipe                  1995
# 59376                        other                 other                  1993
# 59377  communal standpipe multiple    communal standpipe                  1995
# 59378           communal standpipe    communal standpipe                  1995
# 59379           communal standpipe    communal standpipe                  1995
# 59380           communal standpipe    communal standpipe                  1995
# 59381           communal standpipe    communal standpipe                  1995
# 59382           communal standpipe    communal standpipe                  1995
# 59383                    hand pump             hand pump                  1999
# 59384           communal standpipe    communal standpipe                  1995
# 59385                    hand pump             hand pump                  2002
# 59386                    hand pump             hand pump                  2001
# 59387           communal standpipe    communal standpipe                  1999
# 59388              improved spring       improved spring                  1995
# 59389                    hand pump             hand pump                  2001
# 59390                    hand pump             hand pump                  1996
# 59391           communal standpipe    communal standpipe                  1995
# 59392           communal standpipe    communal standpipe                  1995
# 59393                        other                 other                  1995
# 59394           communal standpipe    communal standpipe                  1999
# 59395           communal standpipe    communal standpipe                  1995
# 59396           communal standpipe    communal standpipe                  1995
# 59397                    hand pump             hand pump                  1996
# 59398                    hand pump             hand pump                  1999
# 59399                    hand pump             hand pump                  1999
#
# [59400 rows x 41 columns]

# %%
def con_year(row: pd.DataFrame) -> int:
        ## This function replaces NaN values (earlier converted to zeros) of construction_year
        ## to the average of the construction year (construction_year_avg) for a given record's extraction type 
        if (row['construction_year'] == 0):
            return row['construction_year_avg']
        else:
            return row['construction_year']
            print('same')

# %%
# applying the con_year function to the construction_year column:
wells_test['construction_year'] = wells_test.apply(con_year, axis=1)

# reading out the counts of construction yearrs after imputing the mean for zeros: 
print(wells_test['construction_year'].value_counts())
# Out:
# 1995    7880
# 1999    7491
# 1993    3275
# 2010    2645
# 2009    2622
# 2008    2613
# 1996    2284
# 2000    2190
# 1992    1959
# 2002    1911
# 2007    1587
# 2006    1471
# 2003    1286
# 2001    1267
# 2011    1256
# 2004    1158
# 2012    1108
# 2005    1072
# 1978    1037
# 1998     966
# 1990     954
# 1985     945
# 1980     811
# 1984     779
# 1982     744
# 1994     738
# 1972     708
# 1974     676
# 1997     644
# 1988     521
# 1983     488
# 1975     437
# 1986     434
# 1976     414
# 1970     411
# 1991     324
# 1989     316
# 1987     302
# 1981     238
# 1977     202
# 1979     192
# 1973     184
# 2013     176
# 1971     146
# 1960     102
# 1967      88
# 1963      85
# 1968      77
# 1969      59
# 1964      40
# 1962      30
# 1961      21
# 1965      19
# 1966      17
# Name: construction_year, dtype: int64

# %% [markdown]
# # Building A Base Model
#
# Since we are limited to three online contest submissions per day, we will train/test split the provided training data to create iterative models.

# %% [markdown]
# ### Split into train/test

# %%
X_train, X_test, y_train, y_test = train_test_split(features, targets, random_state=42)

# %%
# creating a list of column names that tries to eliminate the featural redundancy we explored above.
# Constituent features of hierarchical data classifications were all dropped, save for the most granular feature column.
features_list = ['basin', 'region',
       'scheme_management', 'scheme_name',
       'extraction_type',
       'management', 'payment', 
       'water_quality', 'quantity',
       'source', 'waterpoint_type','gps_height', 'longitude', 'latitude', 'num_private', 
        'region_code', 'district_code', 'population', 'construction_year']

# %% [markdown]
# ### Cleaning Data

# %%
wells = features.copy()
wells.shape
# Out:
# (59400, 40)

# %%
def clean(df, feature_list):
    #this takes the df and the list of features we want to clean
    df = df[feature_list]
    
    df = drop_zero_long(df)
    df = con_year_avg(df)
    return df

# %%
## this will live within the "clean" function. It drops records where the longitude equals zero.
def drop_zero_long(df):
    return df.drop(df[df.longitude==0].index)
# wells2 = wells.drop(wells[wells.longitude==0].index)
# wells2

# %%
def con_year(row: pd.DataFrame) -> int:
        ## This function replaces rows with contruction_year == 0 with the average year based upon their extractor type
        if (row['construction_year'] == 0):
            return row['construction_year_avg']
        else:
            return row['construction_year']

# %%
def con_year_avg(df):
    con_year_nonzero = df.replace(0, np.nan)
#     con_year_nonzero = con_year_nonzero.dropna(how='all', axis=1) don't think we need this
    avg_con_years = pd.DataFrame(con_year_nonzero.groupby(['extraction_type']).mean()['construction_year'])
#     avg_con_years['construction_year'] = avg_con_years['construction_year'].astype(int)
    df = df.join(avg_con_years, rsuffix = '_avg', on = 'extraction_type')
    df = df.reset_index()
    df = df.drop(['index'], axis = 1)
    df['construction_year'] = wells_test.apply(con_year, axis=1)
    df = df.drop(['construction_year_avg'], axis = 1)
    return df

# %%
test = con_year_avg(wells)
# test.construction_year.value_counts()

# %%
test = clean(wells, features_list)

# %%
# this is with no list
# def obj_preprocessing(df):
#     '''
#     '''
#     # Clean the df if there are NaNs
#     df = NaN_cleaning(df)
#     #OHE data
#     array_current = ohe_data(df)
#     #return a dataframe of the OHE data
#     return pd.DataFrame(array_current)

# def ohe_data(df):
#     #OHE the data
#     onehotencoder = OneHotEncoder() # Instantiate a One Hot Encoder object 
#     print('One hot encoding data')
#     array_current = onehotencoder.fit_transform(df).toarray()
#     return array_current

# def NaN_cleaning(df):
#     # Replace NaN with "unknown" bin
#     print('Cleaning the data')
#     df = df.replace(np.nan, 'unknown')
#     print(f'Check: Number of rows with nulls: {len(df[df.isna().any(axis=1)])}')
#     return df

# %%
# this is with list
def obj_preprocessing(df, obj_list, ohe, train = True):
    '''
    '''
    df_current = df[obj_list]
    # Clean the df if there are NaNs
    df = NaN_cleaning(df_current)
    #OHE data
    array_current = ohe_data(df, ohe, train)
    #return a dataframe of the OHE data
    return pd.DataFrame(array_current)

def ohe_data(df, ohe, train):
    #OHE the data
    print('One hot encoding data')
    if train:
        array_current = ohe.fit_transform(df).toarray()
    else:
        array_current = ohe.transform(df).toarray()
    return array_current

def NaN_cleaning(df):
    # Replace NaN with "unknown" bin
    print('Cleaning the data')
    df = df.replace(np.nan, 'unknown')
    print(f'Check: Number of rows with nulls: {len(df[df.isna().any(axis=1)])}')
    return df

# %%
obj_pp = obj_preprocessing(objects)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-234-7ac82c4894fa> in <module>()
# ----> 1 obj_pp = obj_preprocessing(features_list)
#
# TypeError: obj_preprocessing() missing 2 required positional arguments: 'obj_list' and 'ohe'

# %% [markdown]
# # FINAL? WORKING PIPELINE

# %%
# Be sure to train/test split before processing DFs
def model_preprocessing(df, feature_list, ohe, train=True):
    df = numerical_clean(df,feature_list)
    
    # below should probably be a funciton for cleanliness
    target = df['status_group']
    df = df.drop(columns='status_group', axis = 1)
#     print(df['status_group'])
    obj_list = obj_lister(df)
    ohe_df = obj_preprocessing(df, obj_list, ohe, train)
    df = df.drop(obj_list, axis=1)
    model_df = df.join(ohe_df)
    return model_df, target

# %% [markdown]
# ## Work below

# %%
wells = features.copy()
wells.shape

# %%
features_list = ['basin', 'region',
       'scheme_management', 'scheme_name',
       'extraction_type',
       'management', 'payment', 
       'water_quality', 'quantity',
       'source', 'waterpoint_type','gps_height', 'longitude', 'latitude', 
        'region_code', 'district_code', 'population', 'construction_year', 'status_group']

# %%
def obj_lister(df):
    # returns a list of columns that contain Objects
    obj_list = []
    for col in df.select_dtypes([np.object]):
        obj_list.append(col)
    return obj_list

# %%
## might not need this
# def ohe_splitter(df):
#     # this is the second step of the pipeline, after train/test split, splitting feature list into objects and numerical lists, for more
#     # processing
#     obj_list = []
    
#     ## appends lists with columns based upon their dtypes
#     for col in df.select_dtypes([np.object]):
#         obj_list.append(col)
#     num_df = df.drop(obj_list)
#     return df[obj_list], num_df

# %%
obj = obj_lister(cleaned)
obj

# %%
ohe_test = obj_preprocessing(cleaned, obj)

# %%
cleaned_drop = cleaned.drop(obj, axis=1)

# %%
model_df = cleaned_drop.join(ohe_test)

# %% [markdown]
# ____

# %% [markdown]
# ## Model 1: Decision Tree

# %%
targets['status_group'].value_counts().sum()

# %%
targets.shape

# %%
ohe = OneHotEncoder(handle_unknown = 'ignore')

# %%
X_train, X_test, y_train, y_test = train_test_split(features, targets, random_state=42)

# %%
joined_train = X_train.join(y_train, lsuffix='_l', rsuffix='_r')

# %%
joined_train_processed, y_train = model_preprocessing(joined_train, features_list, ohe, train = True)

# %%
joined_train_processed.shape

# %%
dtc = DecisionTreeClassifier(random_state=42, max_depth=1) 
dtc.fit(joined_train_processed, y_train)

# %% [markdown]
# Predicts

# %%
joined_test = X_test.join(y_test, lsuffix='_l', rsuffix='_r')

# %%
joined_test.shape

# %%
joined_test_processed, y_test = model_preprocessing(joined_test, features_list, ohe, train=False)

# %%
joined_test_processed.shape

# %%
predicts = dtc.predict(joined_test_processed)

# %%
predicts

# %%
dtc.score(joined_test_processed,predicts)

# %%
joined_test_processed

# %%
y_test

# %%
dtc.decision_path(joined_test_processed)
